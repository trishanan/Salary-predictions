# %% [markdown]
# ## Importing preprocess function and the plot function to clean the data and plot graphs

# %%
import sys
sys.path.insert(0,'./modules')
from preprocess import *

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
train_feature = pd.read_csv(r'C:\Users\Admin\Desktop\salary_predictions\data\train_features.csv')
test_feature = pd.read_csv(r'C:\Users\Admin\Desktop\salary_predictions\data\test_features.csv')
train_salaries = pd.read_csv(r'C:\Users\Admin\Desktop\salary_predictions\data\train_salaries.csv')

# %%
train_df = preprocess_data (train_feature,train_salaries)

# %%
train_df.head()
# Out:
#               jobId companyId         jobType       degree      major  \
# 0  JOB1362684407687    COMP37             CFO      MASTERS       MATH
# 1  JOB1362684407688    COMP19             CEO  HIGH_SCHOOL       NONE
# 2  JOB1362684407689    COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS
# 3  JOB1362684407690    COMP38         MANAGER     DOCTORAL  CHEMISTRY
# 4  JOB1362684407691     COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS
#
#   industry  yearsExperience  milesFromMetropolis  salary
# 0   HEALTH               10                   83     130
# 1      WEB                3                   73     101
# 2   HEALTH               10                   38     137
# 3     AUTO                8                   17     142
# 4  FINANCE                8                   16     163

# %% [markdown]
# ## On the left side, we are plotting the samples for each of the variable
# ## On the right side, we are plotting the distribution of salary for each of the variable

# %%
plot(train_df,'companyId')

# %% [markdown]
# ## The salary is weakly associated with companies.

# %%
plot(train_df,'jobType')

# %% [markdown]
# ## Clearly,there is a positive correlation between jobtype and salary

# %%
plot(train_df,'degree')

# %% [markdown]
# ## Advanced degrees tend to have higher salaries

# %%
plot(train_df,'major')

# %% [markdown]
# ## People with majors of engineering, math and business earn more

# %%
plot(train_df,'industry')

# %% [markdown]
# ## People in web, finance and oil industries tend to have a higher income

# %%
plot(train_df,'yearsExperience')

# %% [markdown]
# ## There is a strong correlation between salary and years of experience

# %%
plot(train_df,'milesFromMetropolis')

# %% [markdown]
# ## There is a negative correlation between salary and distance from Metropolitan area.

# %% [markdown]
# ## Here we will label encode the categorical variables with the mean salary for each category

# %%
train_df1 = label_encode(train_df)

# %% [markdown]
# ## Plotting heatmap by using the customized function created named 'plot_heatmap'

# %%
plot_heatmap(train_df1)

# %% [markdown]
# ## We can observe that salary is strongly correlated with jobType, followed by degree, major and yearsExperience

# %% [markdown]
# ## Also among the features, we see that degree and major has strong correlation whereas jobType has a moderate degree of correlation with degree and major
